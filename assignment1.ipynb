# %% [markdown]
# <a href="https://colab.research.google.com/github/Amaan11205/PRACS/blob/main/assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Import required libraries
import pandas as pd
import seaborn as sns

# 2 & 3. Load dataset
df = sns.load_dataset('titanic')

print("First 5 rows of dataset:")
print(df.head())

# 4. Data Preprocessing

print("\n--- Missing Values ---")
print(df.isnull().sum())

print("\n--- Statistical Summary ---")
print(df.describe())

print("\n--- Dataset Info ---")
print(df.info())

print("\n--- Dimensions of Dataset ---")
print(df.shape)

# 5. Data Formatting

print("\n--- Data Types Before Conversion ---")
print(df.dtypes)

# Convert data types (if needed)
df['age'] = df['age'].astype(float)
df['survived'] = df['survived'].astype(int)

print("\n--- Data Types After Conversion ---")
print(df.dtypes)

# 6. Convert Categorical to Numerical

# Convert 'sex' column
df['sex'] = df['sex'].map({'male': 0, 'female': 1})

# One-hot encoding for 'embarked'
df = pd.get_dummies(df, columns=['embarked'])

print("\n--- Dataset After Encoding ---")
print(df.head())

print("\n--- Final Dataset Info ---")
print(df.info())
# Out:
# First 5 rows of dataset:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#
# --- Missing Values ---
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# ...
