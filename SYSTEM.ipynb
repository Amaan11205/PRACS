# %% [markdown]
# <a href="https://colab.research.google.com/github/Amaan11205/PRACS/blob/main/SYSTEM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def helpdesk():

    print("Help Desk Expert System")
    print("1. Internet Issue")
    print("2. Password Reset")
    print("3. Software Installation")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        print("Solution: Restart the router.")

    elif choice == 2:
        print("Solution: Click on 'Forgot Password'.")

    elif choice == 3:
        print("Solution: Run the setup file.")

    else:
        print("Invalid choice")

helpdesk()
