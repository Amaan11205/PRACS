# %% [markdown]
# <a href="https://colab.research.google.com/github/Amaan11205/PRACS/blob/main/DFSBFS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': [],
    'F': []
}

# -------- DFS --------
visited = []

def dfs(node):

    if node not in visited:

        print(node, end=" ")
        visited.append(node)

        for i in graph[node]:
            dfs(i)

# -------- BFS --------
def bfs(start):

    visited = []
    queue = [start]

    visited.append(start)

    while queue:

        node = queue.pop(0)

        print(node, end=" ")

        for i in graph[node]:

            if i not in visited:

                visited.append(i)
                queue.append(i)

print("DFS Traversal:")
dfs('A')

print("\n")

print("BFS Traversal:")
bfs('A')
# Out:
# DFS Traversal:
# A B D E C F
#
# BFS Traversal:
# A B C D E F
