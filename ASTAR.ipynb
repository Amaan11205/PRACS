# %% [markdown]
# <a href="https://colab.research.google.com/github/Amaan11205/PRACS/blob/main/ASTAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': ['G'],
    'E': ['G'],
    'F': ['G'],
    'G': []
}

h = {
    'A': 6,
    'B': 4,
    'C': 3,
    'D': 2,
    'E': 1,
    'F': 1,
    'G': 0
}
def astar(start, goal):
  open_list=[start]
  visited=[]

  while open_list:
    current=min(open_list,key=lambda x:h[x])
    open_list.remove(current)
    visited.append(current)

    print(current, end=" ")

    if current == goal:
      print("\n goal reached")
      break

    for neighbour in graph[current]:
      if neighbour not in visited:
        open_list.append(neighbour)

astar('A','G')
# Out:
# A C F G
#  goal reached
